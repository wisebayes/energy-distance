# %%
# !pip install -e '/content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/energy-distance-rag-llm/'
# Out:
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/HPMLFinalProject/energy-distance-rag-llm
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for mteb (pyproject.toml) ... done
#   Created wheel for mteb: filename=mteb-1.3.1-0.editable-py3-none-any.whl size=15044 sha256=81e014c4407484643397c7ec213a12a6b952af699bdde374a9fa2ed88d876157
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o7osdv08/wheels/8b/5e/ea/ad6e91fb300c229bf4e95413e6271ae857f5dfac44e094f214
# Successfully built mteb
# ...
#   Attempting uninstall: mteb
#     Found existing installation: mteb 1.3.1
#     Uninstalling mteb-1.3.1:
#       Successfully uninstalled mteb-1.3.1
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/energy-distance-rag-llm/mteb')

# %%
import sys
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/energy-distance-rag-llm/mteb', '/content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/energy-distance-rag-llm/mteb']

# %%
import importlib.metadata as metadata
from importlib.metadata import version

# %%
import mteb
import importlib.metadata as metadata
from importlib.metadata import version
from mteb import MTEB
from sentence_transformers import SentenceTransformer

# Define the sentence-transformers model name
model_name = "mxbai-embed-large-v1"

model = SentenceTransformer("mixedbread-ai/mxbai-embed-large-v1")
evaluation = MTEB(tasks=["ArguAna"])
results = evaluation.run(model, eval_splits=["test"], output_folder=f"results/{model_name}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/171 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/112k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# ...

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import torch

# %%
test = [torch.tensor([[-0.5918,  1.1671, -0.4765, 0.0922, -0.7703, -0.0193],
        [-0.3466, -0.1476, -0.1682,  0.1513, -1.2151, -0.4125],
        [-0.5152,  0.2782, -0.6498,  0.0741, -0.6223, -0.1461],
        [-0.6106,  1.0546, -0.6765,  0.1650, -0.4975, -0.3006],
        [-0.3655,  0.9524, -0.3689,  0.0398, -0.4844, -0.0918],
        [-0.3980,  0.6659, -0.6174,  -0.1167, -0.9929, -0.2422]],
       device='cuda:0'), torch.tensor([[ 0.4620,  0.6605,  0.1483, -0.1143,  0.2061,  0.4677],
        [ 0.4728,  0.1433, -0.0773,  0.0414, -0.5783,  0.3860],
        [ 0.4370,  0.0302, -0.3977,  0.2331, -0.4707,  0.2495],
        [ 0.4350,  0.5197,  0.1827,  -0.1254,  0.3144,  0.4821],
        [ 0.5177,  0.3040,  0.1845,  -0.2058,  0.5670,  0.4719],
        [ 0.5957,  0.3370, -0.0110,  -0.0242, -0.2429,  0.2960]],
       device='cuda:0'), torch.tensor([[-0.4656,  0.0740, -0.4829, 0.2670,  0.3477, -0.1621],
        [-0.3571, -0.4699, -0.7899,  0.0063,  0.2267, -0.1923],
        [-0.5021, -0.7603, -0.1525,  -0.0055, -0.5579, -0.3415],
        [-0.3966, -0.1033, -0.6688,  0.2165,  0.4522, -0.2853],
        [-0.2566, -0.1607, -0.6744,  0.3211,  0.5871, -0.3146],
        [-0.3538, -0.3133, -0.4603,  0.0634, -0.1024, -0.2846]],
       device='cuda:0')]
test = torch.stack(test)
print(test.shape)
# Out:
# torch.Size([3, 6, 6])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd 'drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# CHANGELOG.md  LICENSE   mteb/           pyproject.toml  results/  tests/
# docs/         Makefile  mteb.egg-info/  README.md       scripts/

# %%
cd 'HPMLFinalProject'
# Out:
# /content/drive/MyDrive/Colab Notebooks/HPMLFinalProject

# %%
# !git push private main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
ls
# Out:
# CHANGELOG.md  LICENSE   mteb/           pyproject.toml  results/  tests/
# docs/         Makefile  mteb.egg-info/  README.md       scripts/

# %%
cd 'energy-distance-rag-llm'
# Out:
# /content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/energy-distance-rag-llm

# %%
import torch

# %%
test = [[1., 2., 3., ], [1., 2., 3.], [1., 2., 3.], [3., 4., 5.]]
a = torch.tensor(test)
b = torch.tensor([[3.5, 8.4, 2.1]])
print(b)
print(a.shape[0])
# Out:
# tensor([[3.5000, 8.4000, 2.1000]])
# 4

# %%
# Out:
# Cloning into 'energy-distance-rag-llm'...
# remote: Enumerating objects: 4944, done.
# remote: Counting objects: 100% (4944/4944), done.
# remote: Compressing objects: 100% (1431/1431), done.
# remote: Total 4944 (delta 3425), reused 4944 (delta 3425), pack-reused 0
# Receiving objects: 100% (4944/4944), 1.64 MiB | 5.97 MiB/s, done.
# Resolving deltas: 100% (3425/3425), done.
# Updating files: 100% (291/291), done.

# %%
cd '/content/drive/MyDrive/Colab Notebooks/HPMLFinalProject/'
# Out:
# /content/drive/MyDrive/Colab Notebooks/HPMLFinalProject

# %%
# Out:
# Cloning into 'sentence-transformers-energydistance'...
# remote: Enumerating objects: 8695, done.
# remote: Counting objects: 100% (8695/8695), done.
# remote: Compressing objects: 100% (2552/2552), done.
# remote: Total 8695 (delta 6016), reused 8695 (delta 6016), pack-reused 0
# Receiving objects: 100% (8695/8695), 17.72 MiB | 13.70 MiB/s, done.
# Resolving deltas: 100% (6016/6016), done.
# Updating files: 100% (375/375), done.
